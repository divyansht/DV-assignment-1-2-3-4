# %%
import pandas as pd
import numpy as np
import os

# all_data = pd.DataFrame()
# df = pd.read_csv("D1.csv")
# all_data = all_data.append(df,ignore_index=True)
# df = pd.read_csv("D2.csv")
# all_data = all_data.append(df,ignore_index=True)



path = 'c:\\users\\div15\\downloads\\dataset'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.csv' in file:
            files.append(os.path.join(r, file))

# all_data=pd.DataFrame();
data_list=[]
print(len(files))
for f in files:
    df = pd.read_csv(f)
    data_list.append(df)
#     all_data.append(df,ignore_index=True)

all_data=pd.concat(data_list,axis=0,ignore_index=True)

print(len(data_list))
print(type(all_data))
print(len(all_data))
# Out:
# 2
# 2
# <class 'pandas.core.frame.DataFrame'>
# 68

# %%
(all_data)
# Out:
#     GEOID  SUMLEV  STATE  COUNTY     CBSA    CSA  NECTA  CNECTA  \
# 0       1      40      1     NaN      NaN    NaN    NaN     NaN
# 1   12097      50     12    97.0  36740.0  422.0    NaN     NaN
# 2   12007      50     12     7.0  99999.0  999.0    NaN     NaN
# 3   12027      50     12    27.0  11580.0  999.0    NaN     NaN
# 4   12037      50     12    37.0  99999.0  999.0    NaN     NaN
# ..    ...     ...    ...     ...      ...    ...    ...     ...
# 63  12067      50     12    67.0  99999.0  999.0    NaN     NaN
# 64  12081      50     12    81.0  35840.0  494.0    NaN     NaN
# 65  12091      50     12    91.0  18880.0  999.0    NaN     NaN
# 66  12073      50     12    73.0  45220.0  999.0    NaN     NaN
# 67  12115      50     12   115.0  35840.0  494.0    NaN     NaN
#
#                 NAME   POP100    HU100  POP100.2000  HU100.2000  P001001  \
# 0            Alabama  4779736  2171853      4447100     1963711  4779736
# 1     Osceola County   268685   128170       172493       72293   268685
# 2    Bradford County    28520    11011        26088        9605    28520
# 3      DeSoto County    34862    14590        32209       13608    34862
# 4    Franklin County    11549     8652        11057        7180    11549
# ..               ...      ...      ...          ...         ...      ...
# 63  Lafayette County     8870     3328         7022        2660     8870
# 64    Manatee County   322833   172690       264002      138128   322833
# 65   Okaloosa County   180822    92407       170498       78593   180822
# 66       Leon County   275487   124136       239452      103974   275487
# 67   Sarasota County   379448   228413       325957      182467   379448
#
#     P001001.2000
# 0        4447100
# 1         172493
# 2          26088
# 3          32209
# 4          11057
# ..           ...
# 63          7022
# 64        264002
# 65        170498
# 66        239452
# 67        325957
#
# [68 rows x 15 columns]

# %%
import os

path = 'c:\\users\\div15\\downloads'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.csv' in file:
            files.append(os.path.join(r, file))
            
for f in files:
    print(f)
# Out:
# c:\users\div15\downloads\1. Master H1B Dataset no zero.csv
# c:\users\div15\downloads\1. Master H1B Dataset.csv
# c:\users\div15\downloads\6304 Regression Project Data (1).csv
# c:\users\div15\downloads\6304 Regression Project Data.csv
# c:\users\div15\downloads\Accidental_Drug_Related_Deaths_2012-2018 (1).csv
# c:\users\div15\downloads\Accidental_Drug_Related_Deaths_2012-2018.csv
# c:\users\div15\downloads\Admission_Predict.csv
# c:\users\div15\downloads\Admission_Predict_Ver1.1.csv
# c:\users\div15\downloads\Alarms.csv
# c:\users\div15\downloads\D1.csv
# c:\users\div15\downloads\D2.csv
# c:\users\div15\downloads\Date.csv
# c:\users\div15\downloads\DimCity.csv
# c:\users\div15\downloads\DimState.csv
# c:\users\div15\downloads\DimYear.csv
# c:\users\div15\downloads\FactCrime.csv
# c:\users\div15\downloads\fifa_ranking.csv
# c:\users\div15\downloads\NDHUB.AmbulanceServiceAreas.csv
# c:\users\div15\downloads\NDHUB.SchoolsHigherEducation.csv
# c:\users\div15\downloads\NDHUB.StateParks_0.csv
# c:\users\div15\downloads\res_adolescent_obesity_-_line_chart_r89w-puzn.csv
# c:\users\div15\downloads\res_adolescent_obesity_66ej-yj4q.csv
# c:\users\div15\downloads\res_health_care_cost_growth_2rx6-rfwj.csv
# c:\users\div15\downloads\res_high_school_graduation_rate_-_column_chart_7tgg-akr4.csv
# c:\users\div15\downloads\res_income_poverty_rate_-_line_chart_w3qw-dt6b.csv
# c:\users\div15\downloads\res_physical_activity_padm-ykhv.csv
# c:\users\div15\downloads\Sales_Tax_Rates.csv
# c:\users\div15\downloads\CrimeDataMartDesign\CrimeDataMartDesign\2006 - 2008 Crime in the United States (Data.gov)-CityCrime.csv
# c:\users\div15\downloads\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\iris.csv
# c:\users\div15\downloads\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\iris.data.csv
# c:\users\div15\downloads\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\mtcars.csv
# c:\users\div15\downloads\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\Superstore-Sales.csv
# c:\users\div15\downloads\sqldeveloper-19.2.0.206.2117-x64\sqldeveloper\sqldeveloper\extensions\oracle.datamodeler\templates\ABBREVS_SAMPLE.csv
# c:\users\div15\downloads\sqldeveloper-19.2.0.206.2117-x64\sqldeveloper\sqldeveloper\extensions\oracle.datamodeler\templates\plurals.csv
# c:\users\div15\downloads\sqldeveloper-19.2.1.247.2212-x64\sqldeveloper\sqldeveloper\extensions\oracle.datamodeler\templates\ABBREVS_SAMPLE.csv
# c:\users\div15\downloads\sqldeveloper-19.2.1.247.2212-x64\sqldeveloper\sqldeveloper\extensions\oracle.datamodeler\templates\plurals.csv
